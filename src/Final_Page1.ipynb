# %%
import streamlit as st

# Set page configuration
st.markdown("""
<style>
.small-white-box {
    background-color: rgba(245, 245, 220, 0.95);
    padding: 1.5rem;
    border-radius: 15px;
    box-shadow: 2px 2px 10px rgba(0,0,0,0.1);
    max-width: 500px;
    margin: 2rem auto 1rem auto;
}
</style>

<div class="small-white-box">
<h1 style='text-align: center; margin: 0;'> Media News Analyzer</h1>
</div>
""", unsafe_allow_html=True)

# CSS: Background + white box style
page_bg_img = f"""
<style>
[data-testid="stAppViewContainer"] > .main {{
    background-image: url("https://www.shutterstock.com/image-vector/newspaper-background-torn-paper-style-600nw-2261765635.jpg");
    background-size: cover;
    background-position: center;
    background-repeat: no-repeat;
    background-attachment: fixed;
}}

[data-testid="stHeader"] {{
    background: rgba(255, 255, 255, 0.0);
}}

.white-box {{
    background-color: rgba(245, 245, 220, 0.95);
    padding: 2rem;
    border-radius: 15px;
    box-shadow: 2px 2px 15px rgba(0,0,0,0.1);
    max-width: 1000px;
    margin: 3rem auto;
}}

h1 {{
    text-align: center;
    font-size: 3em;
    color: #1f2937;
    margin-top: 2rem;
}}
</style>
"""
st.markdown(page_bg_img, unsafe_allow_html=True)


#  About Us - white box
st.markdown("""
<div class="white-box">
<h2> About Us</h2>

At the intersection of **data science** and **journalism**, our project tackles the growing concern of **media polarization** through a lens of **data transparency**, **sentiment analysis**, and **topic mapping**.

Unlike traditional media analysis tools, our platform is built to explore *not just what’s being reported, but how it's being reported*.  
We go beyond surface-level headlines to extract **themes**, detect **sentiment polarity**, and identify **clickbait patterns**, enabling a clearer understanding of **bias**, **tone**, and **framing** in the news.
</div>
""", unsafe_allow_html=True)

#  Data Procurement - white box
st.markdown("""
<div class="white-box">
<h3> Data Procurement Strategy</h3>

We collect **real-time** and **historical** news data from three major news APIs:
-  [New York Times API](https://developer.nytimes.com/)
-  [News API (Fox News)](https://newsapi.org/)
-  [Guardian API](https://open-platform.theguardian.com/)

By leveraging these sources, we ensure a diverse mix of **publication styles**, **regional coverage**, and **editorial perspectives**.
</div>
""", unsafe_allow_html=True)

#  Our Goal - white box
st.markdown("""
<div class="white-box">
<h3> Our Goal</h3>

Our mission is to empower users to:

-  Understand what drives **polarized tone** in media reporting  
-  Identify recurring themes in **negative coverage**  
-  Detect **clickbait patterns** through sentiment comparison of titles and content  
-  Reveal **subtopic-level trends** across time and publication sources  

Whether you're investigating **narrative shifts** or visualizing **tone over time**, our platform provides the tools to ask deeper questions about the news we consume daily.
</div>
""", unsafe_allow_html=True)
# Out:
# DeltaGenerator()
